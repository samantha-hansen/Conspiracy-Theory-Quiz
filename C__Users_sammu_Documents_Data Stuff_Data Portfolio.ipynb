# %% [markdown]
# Conspiracy Theorist Quiz

# %%
print("Welcome to the Conspiracy Theorist Quiz! Let's see how much of a conspiracy junkie you are!")

playing = input("Do you want to play? ")
truth = "t"

if playing.lower() != "yes":
    print("Okay! Have a nice day!")
    exit()
    
elif playing.lower() =="yes":
    print("Okay! Let's play!")
    score = 0
    print()

# Question 1
answer = input("Question 1: Lee Harvey Oswald acted alone in the assination of JFK. T/F ")
if answer.lower() == truth:
    print()
    print('Interesting answer. Did you know some believe the CIA may have hired Oswald\n to assasinate the president due to his stances on Communism and the Bay of Pigs Invasion?')
    score = score + 0
    print()
else:
    print()
    print('Interesting answer. Theories range from the CIA hiring Oswald to the Mafia, Cuba, or the Soviet Union arranging the assination.')
    score = score + 1
    print()
    
# Question 2
answer = input("Question 2: The High-Frequency Auroral Research Facility in Gatonka, AK is used only to collect data about radio waves and other atmospheric occurances. T/F ")
if answer.lower() == truth:
    print()
    print('Interesting answer. Did you know some believe the the 180 antennas onsite at the HAARP facility are not only used to collect data but are used as a means of mind control and weather manipulation.')
    score = score + 0
    print()
else:
    print()
    print('Interesting answer. Did you know some believe the the 180 antennas onsite at the HAARP facility are not only used to collect data but are used as a means of mind control and weather manipulation.')
    score = score + 1
    print()
    
#Question 3
answer = input("Question 3: The Denver International Airport serves only as a major transportation hub. T/F ")
if answer.lower() == truth:
    print()
    print('Interesting answer. Theories on the Denver International airport range from containing an underground bunker to being Illuminati headquarters to being built by Neo-Nazis and funded by The New World Airport Commission.')
    score = score + 0
    print()
else:
    print()
    print('Interesting answer. Theories on the Denver International airport range from containing an underground bunker to being Illuminati headquarters to being built by Neo-Nazis and funded by The New World Airport Commission.')
    score = score + 1
    print()
    
#Question 4
answer = input("Question 4: A mountain-dwelling, mythical creature called a sasquatch has been sighted in multiple locations across the united states. T/F ")
if answer.lower() == truth:
    print()
    print('Interesting answer. There are many theories surrounding sasquatch, or bigfoot. There have been over 2,000 alleged sightings in Washington State alone.')
    score = score + 1
    print()
else:
    print()
    print('Interesting answer. There are many theories surrounding sasquatch, or bigfoot. There have been over 2,000 alleged sightings in Washington State alone.')
    score = score + 0
    print()
    
#Question 5
answer = input("Question 5: There is a mega-volcano located under the Yellowstone National Park in Wyoming, that if it were to erupt would wipe out the entire United States and the government knows when it is expected to erupt. T/F ")
if answer.lower() == truth:
    print()
    print('Interesting answer. The active volcano measures 44 miles across and some believe contingency plans have been drawn because the government knows an eruption is imminent.')
    score = score + 1
    print()
else:
    print()
    print('Interesting answer. The active volcano measures 44 miles across and some believe contingency plans have been drawn because the government knows an eruption is imminent.')
    score = score + 0
    print()
    
#Question 6
answer = input("Question 6: The government is using airplanes to drop chemicals on certain areas and the leftover chemicals create streaks in the sky. T/F ")
if answer.lower() == truth:
    print()
    print('Interesting answer. Some people in Idaho believe the government is dropping chemicals from airplanes throughout the year and point to an instance where 2000 geese supposedly fell from the sky after coming in contact with these chemicals.')
    score = score + 1
    print()
else:
    print()
    print('Interesting answer. Some people in Idaho believe the government is dropping chemicals from airplanes throughout the year and point to an instance where 2000 geese supposedly fell from the sky after coming in contact with these chemicals.')
    score = score + 0
    print()
    
#Question 7
answer = input("Question 7: The town of Centrailia, Pennsylvania is home to an underground fire that has been burning since 1962. It was started only to dispose of the trash in the town's landfill. T/F ")
if answer.lower() == truth:
    print()
    print('Interesting answer. While the fire originated in the landfill, it spread to the coal mines beneath the town making uninhabitable. Some believe the government started the fire to force people out of the town and collect the billions of dollars worth of coal.')
    score = score + 0
    print()
else:
    print()
    print('Interesting answer. While the fire originated in the landfill, it spread to the coal mines beneath the town making uninhabitable. Some believe the government started the fire to force people out of the town and collect the billions of dollars worth of coal.')
    score = score + 1
    print()
    
#Question 8
answer = input("Question 8: Bill Gates has utilized COVID-19 vaccines to implant tracking microchips in a large portion of the population. T/F ")
if answer.lower() == truth:
    print()
    print('Interesting answer. In the early days of COVID-19 vaccine development, many unfounded claims circulated via social media regarding the vaccine. One such claim was that people would be implanted with location-tracking microchips.')
    score = score + 1
    print()
else:
    print()
    print('Interesting answer. In the early days of COVID-19 vaccine development, many unfounded claims circulated via social media regarding the vaccine. One such claim was that people would be implanted with location-tracking microchips.')
    score = score + 0
    print()
    
#Question 9
answer = input("Question 9: Jeffrey Epstein commited suicide while awaiting trial for sex trafficking and conspiracy. T/F ")
if answer.lower() == truth:
    print()
    print('Interesting answer. Many believe that Epstein was murdered prior to his trial due to his connections to many rich, famous, or even royal individuals.')
    score = score + 0
    print()
else:
    print()
    print('Interesting answer. Many believe that Epstein was murdered prior to his trial due to his connections to many rich, famous, or even royal individuals.')
    score = score + 1
    print()
    
#Question 10
answer = input("Question 10: The collapse of the twin towers on September 11, 2001 was a result of the impact of the airplanes and resulting damages. T/F ")
if answer.lower() == truth:
    print()
    print('Interesting answer. Some believe that the attack location was predetermined by the government and the destruction of the towers was a result of a planned demolition rather than from damage received by the airplanes and the resulting fires. ')
    score = score + 0
    print()
else:
    print()
    print('Interesting answer. Some believe that the attack location was predetermined by the government and the destruction of the towers was a result of a planned demolition rather than from damage received by the airplanes and the resulting fires. ')
    score = score + 1
    print()
    
print(score)

if score >= 0:
    if (score<3):
        print("Thanks for playing! Here are your results:")
        print()
        print("You have taken the blue pill. No conspiracy theorist here. ")
    elif (score<=6):
        print("Thanks for playing! Here are your results:")
        print()
        print("You have questions. We have answers...maybe.")
    elif  (score>6):
        print("Thanks for playing! Here are your results:")
        print()
        print("You have taken the red pill. You are a conspiracy pro.")
# Out:
# Welcome to the Conspiracy Theorist Quiz! Let's see how much of a conspiracy junkie you are!
